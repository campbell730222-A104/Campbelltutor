# %% [markdown]
# # Python 新手指南：03 資料結構 - 練習題
#
# **作者：** Tsung-Min Pai
# **單位：** NTUEE
#
# ---
#
# ## 📝 練習說明
#
# 這個練習本包含多個資料結構練習題，幫助你熟悉 Python 的四種基本資料結構。
#
# **練習方式：**
# 1. 閱讀每個練習題的說明和註解
# 2. 在標記 `# TODO:` 的地方完成程式碼
# 3. 執行程式碼儲存格來檢查結果
# 4. 確保輸出符合預期結果
#
# **本章內容：**
# - 列表 (Lists) - 有序、可變的資料集合
# - 元組 (Tuples) - 有序、不可變的資料集合
# - 集合 (Sets) - 無序、不重複的資料集合
# - 字典 (Dictionaries) - 鍵值對的資料集合
#
# **提示：** 如果遇到困難，可以參考教學文件或詢問助教！
#
# ---

# %% [markdown]
# ## 練習 1：列表 (Lists) 基礎操作
#
# **目標：** 學會建立、存取和修改列表

# %%
# 練習 1：列表基礎操作
# 練習建立和操作列表

# TODO: 建立一個包含你喜歡的 5 種水果的列表
fruits = []

# TODO: 印出整個水果列表
print("我的水果清單:")


# TODO: 印出第一個和最後一個水果
print(f"第一個水果: {}")
print(f"最後一個水果: {}")

# TODO: 將第二個水果改成 "芒果"


# TODO: 在列表最後新增一個新水果 "草莓"


# TODO: 印出修改後的列表
print("修改後的水果清單:")


# 預期輸出範例：
# 我的水果清單: ['蘋果', '香蕉', '橘子', '葡萄', '鳳梨']
# 第一個水果: 蘋果
# 最後一個水果: 鳳梨
# 修改後的水果清單: ['蘋果', '芒果', '橘子', '葡萄', '鳳梨', '草莓']

# %% [markdown]
# ## 練習 2：列表進階操作
#
# **目標：** 學會使用列表的各種方法和操作

# %%
# 練習 2：列表進階操作
# 練習列表的常用方法

# TODO: 建立一個數字列表，包含 [3, 1, 4, 1, 5, 9, 2, 6]
numbers = []

# TODO: 印出列表的長度
print(f"列表長度: {}")

# TODO: 計算列表中所有數字的總和
total = 
print(f"總和: {total}")

# TODO: 找出列表中的最大值和最小值
max_num = 
min_num = 
print(f"最大值: {max_num}, 最小值: {min_num}")

# TODO: 對列表進行排序（不修改原列表）
sorted_numbers = 
print(f"排序後: {sorted_numbers}")
print(f"原列表: {numbers}")

# TODO: 計算數字 1 在列表中出現的次數
count_1 = 
print(f"數字 1 出現次數: {count_1}")

# TODO: 刪除列表中第一個出現的數字 1


print(f"刪除一個 1 後: {numbers}")

# 預期輸出範例：
# 列表長度: 8
# 總和: 31
# 最大值: 9, 最小值: 1
# 排序後: [1, 1, 2, 3, 4, 5, 6, 9]
# 原列表: [3, 1, 4, 1, 5, 9, 2, 6]
# 數字 1 出現次數: 2
# 刪除一個 1 後: [3, 4, 1, 5, 9, 2, 6]

# %% [markdown]
# ## 練習 3：元組 (Tuples) 基礎操作
#
# **目標：** 學會建立和操作元組

# %%
# 練習 3：元組基礎操作
# 練習建立和使用元組

# TODO: 建立一個座標點元組，表示點 (10, 20)
point = 

# TODO: 印出 x 和 y 座標
print(f"座標點: x={}, y={}")

# TODO: 建立一個包含你個人資訊的元組：(姓名, 年齡, 科系)
personal_info = 

# TODO: 使用元組解包 (tuple unpacking) 取得個別資訊
name, age, major = 

print(f"姓名: {name}")
print(f"年齡: {age}")
print(f"科系: {major}")

# TODO: 建立一個 RGB 顏色元組，表示紅色 (255, 0, 0)
red_color = 

# TODO: 印出顏色資訊
print(f"紅色 RGB 值: R={}, G={}, B={}")

# TODO: 嘗試建立一個只有一個元素的元組（注意語法）
single_tuple = 

print(f"單元素元組: {single_tuple}")
print(f"型別: {type(single_tuple)}")

# 預期輸出範例：
# 座標點: x=10, y=20
# 姓名: 王小明
# 年齡: 20
# 科系: 資訊工程
# 紅色 RGB 值: R=255, G=0, B=0
# 單元素元組: (42,)
# 型別: <class 'tuple'>

# %% [markdown]
# ## 練習 4：集合 (Sets) 基礎操作
#
# **目標：** 學會建立和操作集合，理解集合的特性

# %%
# 練習 4：集合基礎操作
# 練習建立和使用集合

# TODO: 從包含重複元素的列表建立集合
numbers_list = [1, 2, 2, 3, 3, 3, 4, 4, 5]
unique_numbers = 

print(f"原列表: {numbers_list}")
print(f"去重後的集合: {unique_numbers}")

# TODO: 建立兩個興趣集合
alice_interests = {"閱讀", "電影", "旅行", "攝影"}
bob_interests = 

# TODO: 找出共同興趣（交集）
common = 

# TODO: 找出所有興趣（聯集）
all_interests = 

# TODO: 找出只有 Alice 有的興趣（差集）
alice_only = 

print(f"Alice 的興趣: {alice_interests}")
print(f"Bob 的興趣: {bob_interests}")
print(f"共同興趣: {common}")
print(f"所有興趣: {all_interests}")
print(f"只有 Alice 有的興趣: {alice_only}")

# TODO: 新增一個新興趣到 Alice 的集合


print(f"Alice 新增興趣後: {alice_interests}")

# 預期輸出範例：
# 原列表: [1, 2, 2, 3, 3, 3, 4, 4, 5]
# 去重後的集合: {1, 2, 3, 4, 5}
# Alice 的興趣: {'閱讀', '電影', '旅行', '攝影'}
# Bob 的興趣: {'電影', '音樂', '旅行', '運動'}
# 共同興趣: {'電影', '旅行'}
# 所有興趣: {'閱讀', '電影', '旅行', '攝影', '音樂', '運動'}
# 只有 Alice 有的興趣: {'閱讀', '攝影'}
# Alice 新增興趣後: {'閱讀', '電影', '旅行', '攝影', '烹飪'}

# %% [markdown]
# ## 練習 5：字典 (Dictionaries) 基礎操作
#
# **目標：** 學會建立和操作字典

# %%
# 練習 5：字典基礎操作
# 練習建立和使用字典

# TODO: 建立一個學生資訊字典
student = {
    
}

# TODO: 印出學生的姓名和年齡
print(f"學生姓名: {}")
print(f"學生年齡: {}")

# TODO: 新增一個新的鍵值對：電話號碼


# TODO: 修改學生的年齡為 21


# TODO: 印出所有的鍵 (keys)
print(f"所有鍵: {}")

# TODO: 印出所有的值 (values)
print(f"所有值: {}")

# TODO: 印出所有的鍵值對 (items)
print("所有鍵值對:")
for key, value in :
    print(f"  {key}: {value}")

# TODO: 安全地取得一個可能不存在的鍵，並設定預設值
email = 
print(f"Email: {email}")

# 預期輸出範例：
# 學生姓名: 王小明
# 學生年齡: 20
# 所有鍵: dict_keys(['name', 'age', 'major', 'phone'])
# 所有值: dict_values(['王小明', 21, '資訊工程', '0912345678'])
# 所有鍵值對:
#   name: 王小明
#   age: 21
#   major: 資訊工程
#   phone: 0912345678
# Email: 未提供

# %% [markdown]
# ## 練習 6：字典進階應用
#
# **目標：** 練習字典的實際應用場景

# %%
# 練習 6：字典進階應用
# 練習字典在實際問題中的應用

# TODO: 建立一個商品價格字典
prices = {
    
}

# TODO: 建立一個購物車字典（商品名稱：數量）
cart = {
    
}

# TODO: 計算購物車的總金額
total_cost = 0
print("購物明細:")
for item, quantity in cart.items():
    


print(f"總金額: ${total_cost}")

# TODO: 建立一個字典來統計文字中各字母的出現次數
text = "hello world"
letter_count = {}

# 統計每個字母出現的次數（忽略空格）
for char in text:
    


print(f"\n文字 '{text}' 中字母統計:")
for letter, count in sorted(letter_count.items()):
    print(f"'{letter}': {count} 次")

# TODO: 建立巢狀字典 - 班級學生資料
class_info = {
    "class_name": "資工一甲",
    "students": {
        
    }
}

# TODO: 印出班級資訊
print(f"\n班級: {}")
print("學生名單:")
for student_id, info in :
    print(f"  學號 {student_id}: {info['name']}, {info['age']} 歲")

# 預期輸出範例：
# 購物明細:
# 蘋果: 3 個 x $30 = $90
# 香蕉: 2 個 x $25 = $50
# 總金額: $140
# 
# 文字 'hello world' 中字母統計:
# 'd': 1 次
# 'e': 1 次
# 'h': 1 次
# 'l': 3 次
# 'o': 2 次
# 'r': 1 次
# 'w': 1 次
#
# 班級: 資工一甲
# 學生名單:
#   學號 101: 王小明, 20 歲
#   學號 102: 李小華, 19 歲

# %% [markdown]
# ## 練習 7：資料結構轉換
#
# **目標：** 練習不同資料結構之間的轉換

# %%
# 練習 7：資料結構轉換
# 練習在不同資料結構間轉換

# 給定資料
numbers_str = "1,2,3,2,4,3,5,1"

# TODO: 將字串轉換為列表
numbers_list = 

print(f"字串: {numbers_str}")
print(f"轉換為列表: {numbers_list}")

# TODO: 將列表轉換為集合（去除重複）
numbers_set = 

print(f"轉換為集合: {numbers_set}")

# TODO: 將集合轉換回列表並排序
sorted_unique = 

print(f"排序後的唯一值: {sorted_unique}")

# TODO: 建立一個字典，統計每個數字在原列表中的出現次數
count_dict = {}
for num in numbers_list:
    

print(f"數字出現次數: {count_dict}")

# TODO: 從字典的鍵建立一個集合
keys_set = 

print(f"字典鍵的集合: {keys_set}")

# TODO: 建立一個元組，包含最小值、最大值和平均值
int_list = [int(x) for x in numbers_list]
stats = 

print(f"統計資料 (最小, 最大, 平均): {stats}")

# TODO: 將多個學生資料從列表轉換為字典
student_data = [
    ["王小明", 20, "資工系"],
    ["李小華", 19, "電機系"], 
    ["張小美", 21, "數學系"]
]

students_dict = {}
for i, (name, age, major) in enumerate(student_data):
    

print("\n學生資料字典:")
for student_id, info in students_dict.items():
    print(f"學生{student_id}: {info}")

# 預期輸出範例：
# 字串: 1,2,3,2,4,3,5,1
# 轉換為列表: ['1', '2', '3', '2', '4', '3', '5', '1']
# 轉換為集合: {'1', '2', '3', '4', '5'}
# 排序後的唯一值: ['1', '2', '3', '4', '5']
# 數字出現次數: {'1': 2, '2': 2, '3': 2, '4': 1, '5': 1}
# 字典鍵的集合: {'1', '2', '3', '4', '5'}
# 統計資料 (最小, 最大, 平均): (1, 5, 2.625)
# 
# 學生資料字典:
# 學生1: {'name': '王小明', 'age': 20, 'major': '資工系'}
# 學生2: {'name': '李小華', 'age': 19, 'major': '電機系'}
# 學生3: {'name': '張小美', 'age': 21, 'major': '數學系'}

# %% [markdown]
# ## 練習 8：綜合應用題
#
# **目標：** 結合多種資料結構解決實際問題

# %%
# 練習 8-1：學生成績管理系統
# 綜合運用所有資料結構

# TODO: 建立一個完整的成績管理系統
grades_system = {
    "subjects": ["數學", "英文", "程式設計", "物理"],
    "students": {
        
    }
}

print("=== 學生成績管理系統 ===")

# TODO: 計算每個學生的平均成績
print("\n各學生平均成績:")
for student_id, info in grades_system["students"].items():
    

# TODO: 計算每科的平均成績
print("\n各科平均成績:")
for i, subject in enumerate(grades_system["subjects"]):
    

# TODO: 找出成績最高和最低的學生
all_averages = []
for student_id, info in grades_system["students"].items():
    avg = sum(info["grades"]) / len(info["grades"])
    all_averages.append((avg, student_id, info["name"]))



print(f"\n最高平均: {:.1f} 分 - {}")
print(f"最低平均: {:.1f} 分 - {}")

# 預期輸出範例：
# === 學生成績管理系統 ===
# 
# 各學生平均成績:
# 101 王小明: 85.0 分
# 102 李小華: 88.8 分
# 103 張小美: 91.3 分
# 
# 各科平均成績:
# 數學: 85.0 分
# 英文: 88.3 分
# 程式設計: 90.0 分
# 物理: 88.0 分
# 
# 最高平均: 91.3 分 - 張小美
# 最低平均: 85.0 分 - 王小明

# %%
# 練習 8-2：購物網站資料分析
# 模擬電商網站的資料處理

# TODO: 建立商品資料庫
products = {
    
}

# TODO: 建立訂單記錄
orders = [
    
]

print("=== 購物網站資料分析 ===")

# TODO: 計算總銷售額
total_revenue = 0
for order in orders:
    

print(f"總銷售額: ${total_revenue}")

# TODO: 統計每個商品的銷售數量
product_sales = {}
for order in orders:
    

print("\n商品銷售統計:")
for product_id, quantity in product_sales.items():
    product_name = products[product_id]["name"]
    print(f"{product_name}: {quantity} 件")

# TODO: 找出最受歡迎的商品
most_popular = 

print(f"\n最受歡迎商品: {products[most_popular]['name']} ({product_sales[most_popular]} 件)")

# TODO: 計算每個類別的銷售額
category_revenue = {}
for order in orders:
    

print("\n類別銷售額:")
for category, revenue in category_revenue.items():
    print(f"{category}: ${revenue}")

# 預期輸出範例：
# === 購物網站資料分析 ===
# 總銷售額: $4650
# 
# 商品銷售統計:
# iPhone 13: 3 件
# MacBook Pro: 1 件
# AirPods: 5 件
# 
# 最受歡迎商品: AirPods (5 件)
# 
# 類別銷售額:
# 手機: $2970
# 筆電: $1299
# 配件: $380

# %% [markdown]
# ## 🎉 練習完成！
#
# 恭喜你完成了 Python 資料結構的所有練習！
#
# **你已經學會了：**
# - ✅ 列表 (Lists) 的建立、修改和各種操作方法
# - ✅ 元組 (Tuples) 的特性和使用場景
# - ✅ 集合 (Sets) 的去重功能和集合運算
# - ✅ 字典 (Dictionaries) 的鍵值對操作和應用
# - ✅ 不同資料結構之間的轉換
# - ✅ 綜合運用資料結構解決實際問題
#
# **資料結構選擇要點：**
# - 📋 **需要順序且會修改** → 使用列表 (List)
# - 🔒 **需要順序但不會修改** → 使用元組 (Tuple)
# - 🎯 **需要去重或集合運算** → 使用集合 (Set)
# - 🗂️ **需要鍵值對應關係** → 使用字典 (Dictionary)
#
# **下一步：**
# 繼續學習 Python 的函式定義、模組使用等進階概念。
#
# **延伸挑戰：**
# 1. 建立一個完整的圖書館管理系統
# 2. 實作一個簡單的文字分析工具
# 3. 設計一個學生選課系統
#
# 繼續加油！🚀
