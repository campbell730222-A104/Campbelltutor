# %% [markdown]
# # Python 新手指南：04 函式 - 練習題
#
# **作者：** Tsung-Min Pai
# **單位：** NTUEE
#
# ---
#
# ## 📝 練習說明
#
# 這個練習本包含多個函式練習題，幫助你熟悉 Python 的函式定義、呼叫和參數使用。
#
# **練習方式：**
# 1. 閱讀每個練習題的說明和註解
# 2. 在標記 `# TODO:` 的地方完成程式碼
# 3. 執行程式碼儲存格來檢查結果
# 4. 確保輸出符合預期結果
#
# **本章內容：**
# - 函式定義與呼叫
# - 參數類型（位置參數、關鍵字參數、預設參數）
# - 回傳值
# - 變數範圍 (Scope)
# - 內建函式
#
# **提示：** 如果遇到困難，可以參考教學文件或詢問助教！
#
# ---

# %% [markdown]
# ## 練習 1：基本函式定義與呼叫
#
# **目標：** 學會定義和呼叫簡單的函式

# %%
# 練習 1：基本函式定義與呼叫

# TODO: 定義一個函式 greet()，印出 "Hello, World!"
def greet():
    print("bonjour, bienvenue à python")

    

# TODO: 呼叫 greet() 函式

greet()


# TODO: 定義一個函式 introduce(name)，接收一個參數並印出自我介紹
def introduce(name):
    print("bonjour, je m'appelle {nom}")




    

# TODO: 呼叫 introduce() 函式，傳入你的名字

introduce("BoLiao")
# TODO: 定義一個函式 add_numbers(a, b)，回傳兩個數字的和
def add_numbers(a, b):
    return a + b
result = add_numbers(5,4)


    

# TODO: 呼叫 add_numbers() 並印出結果
result =  add_numbers(5,4)
print(f"5 + 3 = {result}")

# 預期輸出：
# Hello, World!
# 嗨，我是王小明！
# 5 + 3 = 8
# Out:
# bonjour, bienvenue à python
# bonjour, je m'appelle {nom}
# 5 + 3 = 9

# %% [markdown]
# ## 練習 2：參數類型練習
#
# **目標：** 學會使用不同類型的參數

# %%
# 練習 2：參數類型練習

# TODO: 定義一個函式 calculate_area(length, width, shape="rectangle")
# 具有預設參數，計算面積
def calculate_area(length, width, shape="rectangle"):
    

# TODO: 使用位置參數呼叫函式
area1 = 
print(f"矩形面積: {area1}")

# TODO: 使用關鍵字參數呼叫函式
area2 = 
print(f"三角形面積: {area2}")

# TODO: 定義一個函式 create_profile(name, age, city="台北", country="台灣")
# 建立個人檔案，具有多個預設參數
def create_profile(name, age, city="台北", country="台灣"):
    

# TODO: 用不同方式呼叫 create_profile()
profile1 = 
profile2 = 
profile3 = 

print("檔案 1:", profile1)
print("檔案 2:", profile2)  
print("檔案 3:", profile3)

# 預期輸出範例：
# 矩形面積: 20
# 三角形面積: 10.0
# 檔案 1: 王小明，20歲，住在台北，台灣
# 檔案 2: 李小華，25歲，住在高雄，台灣
# 檔案 3: 張小美，22歲，住在東京，日本

# %% [markdown]
# ## 練習 3：回傳值練習
#
# **目標：** 學會處理函式的回傳值

# %%
# 練習 3：回傳值練習

# TODO: 定義一個函式 get_max(a, b, c)，回傳三個數字中的最大值
def get_max(a, b, c):
    

# TODO: 定義一個函式 is_even(number)，判斷數字是否為偶數
def is_even(number):
    

# TODO: 定義一個函式 calculate_grade(score)，根據分數回傳等級
def calculate_grade(score):
    

# TODO: 定義一個函式 get_circle_info(radius)，回傳圓的面積和周長
import math

def get_circle_info(radius):
    

# 測試函式
print(f"最大值: {get_max(5, 12, 8)}")
print(f"10 是偶數嗎？ {is_even(10)}")
print(f"7 是偶數嗎？ {is_even(7)}")
print(f"85 分的等級: {calculate_grade(85)}")

# TODO: 使用 get_circle_info() 並處理回傳的多個值
area, circumference = 
print(f"半徑 5 的圓：面積 = {area:.2f}, 周長 = {circumference:.2f}")

# 預期輸出：
# 最大值: 12
# 10 是偶數嗎？ True
# 7 是偶數嗎？ False
# 85 分的等級: B
# 半徑 5 的圓：面積 = 78.54, 周長 = 31.42

# %% [markdown]
# ## 練習 4：變數範圍 (Scope)
#
# **目標：** 理解區域變數和全域變數的差異

# %%
# 練習 4：變數範圍練習

# 全域變數
global_var = "我是全域變數"
counter = 0

# TODO: 定義一個函式 test_local_scope()，展示區域變數
def test_local_scope():
    local_var = "我是區域變數"
    global_var = "我是函式內的區域變數"  # 這不會改變全域變數
    


# TODO: 定義一個函式 increment_counter()，修改全域變數
def increment_counter():
    

# TODO: 定義一個函式 get_counter_value()，回傳計數器值  
def get_counter_value():
    

# 測試變數範圍
print("呼叫函式前:")
print(f"全域變數: {global_var}")
print(f"計數器: {counter}")

test_local_scope()
print(f"\n呼叫 test_local_scope() 後:")
print(f"全域變數: {global_var}")  # 應該沒有改變

# TODO: 呼叫 increment_counter() 三次



print(f"\n增加計數器後: {get_counter_value()}")

# 嘗試存取區域變數會產生錯誤
# print(local_var)  # 這行會產生 NameError

# 預期輸出：
# 呼叫函式前:
# 全域變數: 我是全域變數
# 計數器: 0
# 
# 函式內的全域變數: 我是全域變數
# 函式內的區域變數: 我是區域變數
# 
# 呼叫 test_local_scope() 後:
# 全域變數: 我是全域變數
# 
# 增加計數器後: 3

# %% [markdown]
# ## 練習 5：內建函式應用
#
# **目標：** 熟悉常用的內建函式

# %%
# 練習 5：內建函式應用

# 數據列表
numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
names = ["Alice", "Bob", "Charlie", "David", "Eve"]

# TODO: 使用內建函式分析數據
print("數字列表:", numbers)
print(f"列表長度: {}")
print(f"最大值: {}")
print(f"最小值: {}")
print(f"總和: {}")
print(f"排序後: {}")

# TODO: 使用 enumerate() 和 zip() 函式
print("\n使用 enumerate():")
for i, name in :
    print(f"{i+1}. {name}")

scores = [85, 92, 78, 95, 88]
print("\n使用 zip():")
for name, score in :
    print(f"{name}: {score} 分")

# TODO: 使用 map() 和 filter() 函式
# 將所有數字平方
squared = 
print(f"\n平方後: {list(squared)}")

# 篩選出偶數
evens = 
print(f"偶數: {list(evens)}")

# TODO: 使用 any() 和 all() 函式
test_scores = [85, 92, 78, 95, 88]
passing_scores = [x >= 60 for x in test_scores]

print(f"\n所有分數: {test_scores}")
print(f"是否有人及格: {}")
print(f"是否全部及格: {}")

# TODO: 使用 round() 和 abs() 函式
float_numbers = [3.14159, -2.718, 1.414, -0.577]
print(f"\n原始數字: {float_numbers}")
print(f"四捨五入到小數點後2位: {}")
print(f"絕對值: {}")

# 預期輸出範例：
# 數字列表: [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
# 列表長度: 10
# 最大值: 9
# 最小值: 1
# 總和: 39
# 排序後: [1, 1, 2, 3, 3, 4, 5, 5, 6, 9]
# ...

# %% [markdown]
# ## 練習 6：遞迴函式
#
# **目標：** 理解遞迴函式的概念和應用

# %%
# 練習 6：遞迴函式

# TODO: 定義一個遞迴函式 factorial(n)，計算階乘
def factorial(n):
    

# TODO: 定義一個遞迴函式 fibonacci(n)，計算費波那契數列
def fibonacci(n):
    

# TODO: 定義一個遞迴函式 countdown(n)，倒數計時
def countdown(n):
    

# TODO: 定義一個遞迴函式 sum_digits(n)，計算數字各位數的和
def sum_digits(n):
    

# 測試遞迴函式
print("階乘測試:")
for i in range(1, 6):
    print(f"{i}! = {factorial(i)}")

print("\n費波那契數列:")
for i in range(1, 11):
    print(f"F({i}) = {fibonacci(i)}")

print("\n倒數計時:")
countdown(5)

print("\n數字各位數的和:")
test_numbers = [123, 456, 789, 9876]
for num in test_numbers:
    print(f"{num} 的各位數和 = {sum_digits(num)}")

# 預期輸出範例：
# 階乘測試:
# 1! = 1
# 2! = 2
# 3! = 6
# 4! = 24
# 5! = 120
# 
# 費波那契數列:
# F(1) = 1
# F(2) = 1
# F(3) = 2
# ...
# 
# 倒數計時:
# 5
# 4
# 3
# 2
# 1
# 發射！
# 
# 數字各位數的和:
# 123 的各位數和 = 6
# 456 的各位數和 = 15
# ...

# %% [markdown]
# ## 練習 7：綜合應用
#
# **目標：** 綜合運用函式解決實際問題

# %%
# 練習 7：綜合應用 - 學生成績管理系統

# TODO: 定義函式 calculate_average(scores)，計算平均分數
def calculate_average(scores):
    

# TODO: 定義函式 get_letter_grade(average)，根據平均分數回傳等級
def get_letter_grade(average):
    

# TODO: 定義函式 is_passing(average, passing_grade=60)，判斷是否及格
def is_passing(average, passing_grade=60):
    

# TODO: 定義函式 analyze_student(name, scores)，分析學生成績
def analyze_student(name, scores):
    

# TODO: 定義函式 class_statistics(students_data)，分析全班統計
def class_statistics(students_data):
    

# 測試資料
students = {
    "王小明": [85, 92, 78, 88, 90],
    "李小華": [76, 84, 82, 79, 85],
    "張小美": [95, 98, 92, 96, 94],
    "陳小強": [65, 70, 68, 72, 75],
    "劉小玉": [45, 55, 50, 48, 52]
}

print("=== 個別學生分析 ===")
for name, scores in students.items():
    analyze_student(name, scores)
    print()

print("=== 全班統計 ===")
class_statistics(students)

# 預期輸出範例：
# === 個別學生分析 ===
# 學生：王小明
# 各科成績：[85, 92, 78, 88, 90]
# 平均成績：86.6
# 等級：B
# 及格狀態：及格
# 
# === 全班統計 ===
# 全班人數：5
# 全班平均：74.8
# 最高平均：95.0 (張小美)
# 最低平均：50.0 (劉小玉)
# 及格人數：4/5 (80.0%)

# %% [markdown]
# ## 🎉 練習完成！
#
# 恭喜你完成了 Python 函式的所有練習！
#
# **你已經學會了：**
# - ✅ 函式的定義和呼叫
# - ✅ 位置參數、關鍵字參數和預設參數的使用
# - ✅ 函式回傳值的處理
# - ✅ 變數範圍 (Scope) 的概念
# - ✅ 常用內建函式的應用
# - ✅ 遞迴函式的實作
# - ✅ 綜合運用函式解決實際問題
#
# **函式設計原則：**
# - 🎯 **單一職責**：一個函式只做一件事
# - 📝 **清楚命名**：函式名稱要表達其功能
# - 🔧 **可重複使用**：設計通用性的函式
# - 📊 **適當回傳**：回傳有意義的值
#
# **下一步：**
# 繼續學習 Python 的錯誤處理、檔案操作等進階主題。
#
# **延伸挑戰：**
# 1. 建立一個完整的計算機程式（加減乘除、科學計算）
# 2. 實作一個密碼強度檢查器
# 3. 設計一個文字處理工具組
#
# 繼續加油！🚀
